# %%
from metrics.visualization_metrics import visualization
import pandas as pd

# %%
# load full data and slice to get original and generated data
full_data = pd.read_csv("emotion_output.csv")
ori_data = full_data.iloc[:635]
generated_data = full_data.iloc[635:]

# convert to np array for visualization function
ori_data = ori_data.to_numpy().reshape((ori_data.shape[0], ori_data.shape[1], 1))
generated_data = generated_data.to_numpy().reshape((generated_data.shape[0], generated_data.shape[1], 1))
# Out:
# [t-SNE] Computing 121 nearest neighbors...
# [t-SNE] Indexed 1270 samples in 0.006s...
# [t-SNE] Computed neighbors for 1270 samples in 0.092s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 1270
# [t-SNE] Computed conditional probabilities for sample 1270 / 1270
# [t-SNE] Mean sigma: 0.103829
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 57.573261
# [t-SNE] KL divergence after 300 iterations: 0.666725

# %%
visualization(ori_data, generated_data, 'pca')

# %%
visualization(ori_data, generated_data, 'tsne')
